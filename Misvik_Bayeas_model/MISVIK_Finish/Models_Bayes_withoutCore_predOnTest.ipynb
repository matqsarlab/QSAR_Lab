# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import plotly.figure_factory as ff
from sklearn.metrics import classification_report
import itertools
from QSAR_Lab.Misvik_Bayeas_model.models import CoreModel, CombinationModel
from QSAR_Lab.Misvik_Bayeas_model.comparison import observe, compare

from sklearn.naive_bayes import GaussianNB

# %%
my_model = GaussianNB()

# %% [markdown]
# # OX test

# %%
train_a549 = pd.read_excel("Data/OX/a549_data.xlsx", sheet_name=1, index_col=0)
test_a549 = pd.read_excel("Data/OX/a549_data.xlsx", sheet_name=2, index_col=0)
toxic_a549 = pd.read_excel("Data/OX/a549_data.xlsx", sheet_name=3, index_col=0)

train_beas = pd.read_excel("Data/OX/beas_data.xlsx", sheet_name=1, index_col=0)
test_beas = pd.read_excel("Data/OX/beas_data.xlsx", sheet_name=2, index_col=0)
toxic_beas = pd.read_excel("Data/OX/beas_data.xlsx", sheet_name=3, index_col=0)

train_hep = pd.read_excel("Data/OX/hepg2_data.xlsx", sheet_name=1, index_col=0)
test_hep = pd.read_excel("Data/OX/hepg2_data.xlsx", sheet_name=2, index_col=0)
toxic_hep = pd.read_excel("Data/OX/hepg2_data.xlsx", sheet_name=3, index_col=0)

# %%
# Ilosc toksycznych NMs w zbiorze testowym
tox_in_test = 3

# %%
a549 = CombinationModel(my_model, train_a549,test_a549,toxic_a549,tox_in_test)
beas = CombinationModel(my_model, train_beas,test_beas,toxic_beas,2)
hep = CombinationModel(my_model, train_hep,test_hep,toxic_hep,2)

# %% [markdown]
# ## Model A549

# %%
# a549.show_models = False
# x = a549.create_models

# %%
# a549.mean_calc

# %%
obs = pd.read_excel("Data/OX/a549_data.xlsx", index_col=0)
table = compare(obs, a549.predict_on_test)
table
# Out:
# __predOnTest from func:  True
# CREATE_DATA - number of sets: 7359
# __predOnTest GLOBAL:  True
# ELSE
# <style type="text/css">
# #T_8bb8e_row0_col0, #T_8bb8e_row0_col1, #T_8bb8e_row8_col0, #T_8bb8e_row8_col1, #T_8bb8e_row10_col0, #T_8bb8e_row10_col1, #T_8bb8e_row16_col0, #T_8bb8e_row16_col1 {
#   background-color: cornflowerblue;
# }
# #T_8bb8e_row1_col0, #T_8bb8e_row1_col1, #T_8bb8e_row3_col0, #T_8bb8e_row3_col1, #T_8bb8e_row4_col0, #T_8bb8e_row4_col1, #T_8bb8e_row6_col0, #T_8bb8e_row6_col1, #T_8bb8e_row7_col0, #T_8bb8e_row7_col1, #T_8bb8e_row9_col0, #T_8bb8e_row9_col1, #T_8bb8e_row11_col0, #T_8bb8e_row11_col1, #T_8bb8e_row12_col0, #T_8bb8e_row12_col1, #T_8bb8e_row13_col0, #T_8bb8e_row13_col1, #T_8bb8e_row14_col0, #T_8bb8e_row14_col1, #T_8bb8e_row18_col0, #T_8bb8e_row18_col1, #T_8bb8e_row19_col0, #T_8bb8e_row19_col1, #T_8bb8e_row20_col0, #T_8bb8e_row20_col1 {
#   background-color: white;
# }
# #T_8bb8e_row2_col0, #T_8bb8e_row2_col1, #T_8bb8e_row5_col0, #T_8bb8e_row5_col1, #T_8bb8e_row15_col0, #T_8bb8e_row15_col1, #T_8bb8e_row17_col0, #T_8bb8e_row17_col1 {
#   background-color: plum;
# }
# </style>
# <table id="T_8bb8e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8bb8e_level0_col0" class="col_heading level0 col0" >Observed Toxicity</th>
#       <th id="T_8bb8e_level0_col1" class="col_heading level0 col1" >Predicted Toxicity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8bb8e_level0_row0" class="row_heading level0 row0" >1) DQ-12, </th>
#       <td id="T_8bb8e_row0_col0" class="data row0 col0" >Non-Toxic</td>
#       <td id="T_8bb8e_row0_col1" class="data row0 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_8bb8e_level0_row1" class="row_heading level0 row1" >2) JRCNM01005a (TiO2, =NM-105),</th>
#       <td id="T_8bb8e_row1_col0" class="data row1 col0" >Non-Toxic</td>
#       <td id="T_8bb8e_row1_col1" class="data row1 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_8bb8e_level0_row2" class="row_heading level0 row2" >3) JRCNM01101a (ZnO, =NM111),</th>
#       <td id="T_8bb8e_row2_col0" class="data row2 col0" >Toxic</td>
#       <td id="T_8bb8e_row2_col1" class="data row2 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_8bb8e_level0_row3" class="row_heading level0 row3" >4) JRCNM04000a (MWCNT, =NM-400),</th>
#       <td id="T_8bb8e_row3_col0" class="data row3 col0" >Non-Toxic</td>
#       <td id="T_8bb8e_row3_col1" class="data row3 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_8bb8e_level0_row4" class="row_heading level0 row4" >5) JRCNM04002a (MWCNT, =NM-402),</th>
#       <td id="T_8bb8e_row4_col0" class="data row4 col0" >Non-Toxic</td>
#       <td id="T_8bb8e_row4_col1" class="data row4 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_8bb8e_level0_row5" class="row_heading level0 row5" >6) JRCNM40011a (Mitsui-7),</th>
#       <td id="T_8bb8e_row5_col0" class="data row5 col0" >Toxic</td>
#       <td id="T_8bb8e_row5_col1" class="data row5 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_8bb8e_level0_row6" class="row_heading level0 row6" >7) JRCNM50001a (BaSO4, =NM220),</th>
#       <td id="T_8bb8e_row6_col0" class="data row6 col0" >Non-Toxic</td>
#       <td id="T_8bb8e_row6_col1" class="data row6 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_8bb8e_level0_row7" class="row_heading level0 row7" >8) JRCNM62101a (ZnO),</th>
#       <td id="T_8bb8e_row7_col0" class="data row7 col0" >Non-Toxic</td>
#       <td id="T_8bb8e_row7_col1" class="data row7 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_8bb8e_level0_row8" class="row_heading level0 row8" >9) NM-105 (TiO2)</th>
#       <td id="T_8bb8e_row8_col0" class="data row8 col0" >Non-Toxic</td>
#       <td id="T_8bb8e_row8_col1" class="data row8 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_8bb8e_level0_row9" class="row_heading level0 row9" >10) NM-110 (ZnO), </th>
#       <td id="T_8bb8e_row9_col0" class="data row9 col0" >Toxic</td>
#       <td id="T_8bb8e_row9_col1" class="data row9 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_8bb8e_level0_row10" class="row_heading level0 row10" >11) NM-111 (ZnO), </th>
#       <td id="T_8bb8e_row10_col0" class="data row10 col0" >Non-Toxic</td>
#       <td id="T_8bb8e_row10_col1" class="data row10 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_8bb8e_level0_row11" class="row_heading level0 row11" >12) NM-113 (ZnO),</th>
#       <td id="T_8bb8e_row11_col0" class="data row11 col0" >Toxic</td>
#       <td id="T_8bb8e_row11_col1" class="data row11 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_8bb8e_level0_row12" class="row_heading level0 row12" >13) NM-200 (SiO2),</th>
#       <td id="T_8bb8e_row12_col0" class="data row12 col0" >Non-Toxic</td>
#       <td id="T_8bb8e_row12_col1" class="data row12 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_8bb8e_level0_row13" class="row_heading level0 row13" >14) NM-212 (CeO2),</th>
#       <td id="T_8bb8e_row13_col0" class="data row13 col0" >Non-Toxic</td>
#       <td id="T_8bb8e_row13_col1" class="data row13 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_8bb8e_level0_row14" class="row_heading level0 row14" >15) NM-220 (BaSO4),</th>
#       <td id="T_8bb8e_row14_col0" class="data row14 col0" >Non-Toxic</td>
#       <td id="T_8bb8e_row14_col1" class="data row14 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_8bb8e_level0_row15" class="row_heading level0 row15" >16) NM-300k (Ag),</th>
#       <td id="T_8bb8e_row15_col0" class="data row15 col0" >Toxic</td>
#       <td id="T_8bb8e_row15_col1" class="data row15 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_8bb8e_level0_row16" class="row_heading level0 row16" >18) NM-302 (Ag-rod),</th>
#       <td id="T_8bb8e_row16_col0" class="data row16 col0" >Non-Toxic</td>
#       <td id="T_8bb8e_row16_col1" class="data row16 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_8bb8e_level0_row17" class="row_heading level0 row17" >20) TiO2 E171-Venator, </th>
#       <td id="T_8bb8e_row17_col0" class="data row17 col0" >Toxic</td>
#       <td id="T_8bb8e_row17_col1" class="data row17 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_8bb8e_level0_row18" class="row_heading level0 row18" >21) JRCNM02102a (CeO2), </th>
#       <td id="T_8bb8e_row18_col0" class="data row18 col0" >Non-Toxic</td>
#       <td id="T_8bb8e_row18_col1" class="data row18 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_8bb8e_level0_row19" class="row_heading level0 row19" >22) Sigma Silver #576832, </th>
#       <td id="T_8bb8e_row19_col0" class="data row19 col0" >Toxic</td>
#       <td id="T_8bb8e_row19_col1" class="data row19 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_8bb8e_level0_row20" class="row_heading level0 row20" >23) carbon black,</th>
#       <td id="T_8bb8e_row20_col0" class="data row20 col0" >Non-Toxic</td>
#       <td id="T_8bb8e_row20_col1" class="data row20 col1" >Non-Toxic</td>
#     </tr>
#   </tbody>
# </table>

# %%
a549.mean_calc
# Out:
# TRAIN SET:
# Accuracy = 0.8655970337584687
# Precison = 0.7071690641197368
# Recall = 0.9992526158445441
# tn = 8.121348009240386
# fp = 1.878651990759614
# fn = 0.0029895366218236174
# tp = 3.9970104633781762
#
# TEST SET:
# Accuracy = 0.6080601013336437
# Precison = 0.5808084043510051
# Recall = 0.6080601013336437
# tn = 3.0479684739774426
# fp = 0.9520315260225574
# fn = 1.791547764641935
# tp = 1.208452235358065
# 0

# %% [markdown]
# ## Model Beas

# %%
# beas.show_models = False
# beas.create_models

# %%
# beas.mean_calc

# %%
obs = pd.read_excel("Data/OX/beas_data.xlsx", index_col=0)
table = compare(obs, beas.predict_on_test)
table
# Out:
# __predOnTest from func:  True
# CREATE_DATA - number of sets: 5358
# __predOnTest GLOBAL:  True
# ELSE
# <style type="text/css">
# #T_fde6a_row0_col0, #T_fde6a_row0_col1, #T_fde6a_row1_col0, #T_fde6a_row1_col1, #T_fde6a_row2_col0, #T_fde6a_row2_col1, #T_fde6a_row3_col0, #T_fde6a_row3_col1, #T_fde6a_row4_col0, #T_fde6a_row4_col1, #T_fde6a_row5_col0, #T_fde6a_row5_col1, #T_fde6a_row6_col0, #T_fde6a_row6_col1, #T_fde6a_row7_col0, #T_fde6a_row7_col1, #T_fde6a_row8_col0, #T_fde6a_row8_col1, #T_fde6a_row9_col0, #T_fde6a_row9_col1, #T_fde6a_row10_col0, #T_fde6a_row10_col1, #T_fde6a_row11_col0, #T_fde6a_row11_col1, #T_fde6a_row12_col0, #T_fde6a_row12_col1, #T_fde6a_row13_col0, #T_fde6a_row13_col1, #T_fde6a_row14_col0, #T_fde6a_row14_col1, #T_fde6a_row15_col0, #T_fde6a_row15_col1, #T_fde6a_row16_col0, #T_fde6a_row16_col1, #T_fde6a_row18_col0, #T_fde6a_row18_col1, #T_fde6a_row19_col0, #T_fde6a_row19_col1, #T_fde6a_row20_col0, #T_fde6a_row20_col1 {
#   background-color: white;
# }
# #T_fde6a_row17_col0, #T_fde6a_row17_col1 {
#   background-color: plum;
# }
# </style>
# <table id="T_fde6a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fde6a_level0_col0" class="col_heading level0 col0" >Observed Toxicity</th>
#       <th id="T_fde6a_level0_col1" class="col_heading level0 col1" >Predicted Toxicity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fde6a_level0_row0" class="row_heading level0 row0" >1) DQ-12, </th>
#       <td id="T_fde6a_row0_col0" class="data row0 col0" >Toxic</td>
#       <td id="T_fde6a_row0_col1" class="data row0 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_fde6a_level0_row1" class="row_heading level0 row1" >2) JRCNM01005a (TiO2, =NM-105),</th>
#       <td id="T_fde6a_row1_col0" class="data row1 col0" >Non-Toxic</td>
#       <td id="T_fde6a_row1_col1" class="data row1 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_fde6a_level0_row2" class="row_heading level0 row2" >3) JRCNM01101a (ZnO, =NM111),</th>
#       <td id="T_fde6a_row2_col0" class="data row2 col0" >Toxic</td>
#       <td id="T_fde6a_row2_col1" class="data row2 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_fde6a_level0_row3" class="row_heading level0 row3" >4) JRCNM04000a (MWCNT, =NM-400),</th>
#       <td id="T_fde6a_row3_col0" class="data row3 col0" >Non-Toxic</td>
#       <td id="T_fde6a_row3_col1" class="data row3 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_fde6a_level0_row4" class="row_heading level0 row4" >5) JRCNM04002a (MWCNT, =NM-402),</th>
#       <td id="T_fde6a_row4_col0" class="data row4 col0" >Non-Toxic</td>
#       <td id="T_fde6a_row4_col1" class="data row4 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_fde6a_level0_row5" class="row_heading level0 row5" >6) JRCNM40011a (Mitsui-7) MWCNT,</th>
#       <td id="T_fde6a_row5_col0" class="data row5 col0" >Non-Toxic</td>
#       <td id="T_fde6a_row5_col1" class="data row5 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_fde6a_level0_row6" class="row_heading level0 row6" >7) JRCNM50001a (BaSO4, =NM220),</th>
#       <td id="T_fde6a_row6_col0" class="data row6 col0" >Non-Toxic</td>
#       <td id="T_fde6a_row6_col1" class="data row6 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_fde6a_level0_row7" class="row_heading level0 row7" >8) JRCNM62101a (ZnO),</th>
#       <td id="T_fde6a_row7_col0" class="data row7 col0" >Non-Toxic</td>
#       <td id="T_fde6a_row7_col1" class="data row7 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_fde6a_level0_row8" class="row_heading level0 row8" >9) NM-105 (TiO2)</th>
#       <td id="T_fde6a_row8_col0" class="data row8 col0" >Non-Toxic</td>
#       <td id="T_fde6a_row8_col1" class="data row8 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_fde6a_level0_row9" class="row_heading level0 row9" >10) NM-110 (ZnO), </th>
#       <td id="T_fde6a_row9_col0" class="data row9 col0" >Non-Toxic</td>
#       <td id="T_fde6a_row9_col1" class="data row9 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_fde6a_level0_row10" class="row_heading level0 row10" >11) NM-111 (ZnO), </th>
#       <td id="T_fde6a_row10_col0" class="data row10 col0" >Toxic</td>
#       <td id="T_fde6a_row10_col1" class="data row10 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_fde6a_level0_row11" class="row_heading level0 row11" >12) NM-113 (ZnO),</th>
#       <td id="T_fde6a_row11_col0" class="data row11 col0" >Non-Toxic</td>
#       <td id="T_fde6a_row11_col1" class="data row11 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_fde6a_level0_row12" class="row_heading level0 row12" >13) NM-200 (SiO2),</th>
#       <td id="T_fde6a_row12_col0" class="data row12 col0" >Non-Toxic</td>
#       <td id="T_fde6a_row12_col1" class="data row12 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_fde6a_level0_row13" class="row_heading level0 row13" >14) NM-212 (CeO2),</th>
#       <td id="T_fde6a_row13_col0" class="data row13 col0" >Non-Toxic</td>
#       <td id="T_fde6a_row13_col1" class="data row13 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_fde6a_level0_row14" class="row_heading level0 row14" >15) NM-220 (BaSO4),</th>
#       <td id="T_fde6a_row14_col0" class="data row14 col0" >Non-Toxic</td>
#       <td id="T_fde6a_row14_col1" class="data row14 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_fde6a_level0_row15" class="row_heading level0 row15" >16) NM-300k (Ag),</th>
#       <td id="T_fde6a_row15_col0" class="data row15 col0" >Non-Toxic</td>
#       <td id="T_fde6a_row15_col1" class="data row15 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_fde6a_level0_row16" class="row_heading level0 row16" >18) NM-302 (Ag-rod),</th>
#       <td id="T_fde6a_row16_col0" class="data row16 col0" >Non-Toxic</td>
#       <td id="T_fde6a_row16_col1" class="data row16 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_fde6a_level0_row17" class="row_heading level0 row17" >20) TiO2 E171-Venator, </th>
#       <td id="T_fde6a_row17_col0" class="data row17 col0" >Toxic</td>
#       <td id="T_fde6a_row17_col1" class="data row17 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_fde6a_level0_row18" class="row_heading level0 row18" >21) JRCNM02102a (CeO2), </th>
#       <td id="T_fde6a_row18_col0" class="data row18 col0" >Non-Toxic</td>
#       <td id="T_fde6a_row18_col1" class="data row18 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_fde6a_level0_row19" class="row_heading level0 row19" >22) Sigma Silver #576832, </th>
#       <td id="T_fde6a_row19_col0" class="data row19 col0" >Non-Toxic</td>
#       <td id="T_fde6a_row19_col1" class="data row19 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_fde6a_level0_row20" class="row_heading level0 row20" >23) carbon black,</th>
#       <td id="T_fde6a_row20_col0" class="data row20 col0" >Non-Toxic</td>
#       <td id="T_fde6a_row20_col1" class="data row20 col1" >Non-Toxic</td>
#     </tr>
#   </tbody>
# </table>

# %%
beas.mean_calc
# Out:
# TRAIN SET:
# Accuracy = 0.925544357347269
# Precison = 0.7207913400522583
# Recall = 1.0
# tn = 11.883165360209032
# fp = 1.1168346397909668
# fn = 0.0
# tp = 2.0
#
# TEST SET:
# Accuracy = 0.8220107005101406
# Precison = 0.6871345029239767
# Recall = 0.8220107005101406
# tn = 4.0
# fp = 0.0
# fn = 1.0679357969391563
# tp = 0.9320642030608436
# 0

# %% [markdown]
# ## Model HepG2

# %%
# hep.show_models = False
# hep.create_models

# %%
# hep.mean_calc

# %%
obs = pd.read_excel("Data/OX/hepg2_data.xlsx", index_col=0)
table = compare(obs, hep.predict_on_test)
table
# Out:
# __predOnTest from func:  True
# CREATE_DATA - number of sets: 10465
# __predOnTest GLOBAL:  True
# ELSE
# <style type="text/css">
# #T_c0fd7_row0_col0, #T_c0fd7_row0_col1, #T_c0fd7_row1_col0, #T_c0fd7_row1_col1, #T_c0fd7_row2_col0, #T_c0fd7_row2_col1, #T_c0fd7_row3_col0, #T_c0fd7_row3_col1, #T_c0fd7_row4_col0, #T_c0fd7_row4_col1, #T_c0fd7_row5_col0, #T_c0fd7_row5_col1, #T_c0fd7_row6_col0, #T_c0fd7_row6_col1, #T_c0fd7_row8_col0, #T_c0fd7_row8_col1, #T_c0fd7_row10_col0, #T_c0fd7_row10_col1, #T_c0fd7_row12_col0, #T_c0fd7_row12_col1, #T_c0fd7_row13_col0, #T_c0fd7_row13_col1, #T_c0fd7_row14_col0, #T_c0fd7_row14_col1, #T_c0fd7_row15_col0, #T_c0fd7_row15_col1, #T_c0fd7_row16_col0, #T_c0fd7_row16_col1, #T_c0fd7_row17_col0, #T_c0fd7_row17_col1, #T_c0fd7_row18_col0, #T_c0fd7_row18_col1, #T_c0fd7_row19_col0, #T_c0fd7_row19_col1, #T_c0fd7_row20_col0, #T_c0fd7_row20_col1 {
#   background-color: white;
# }
# #T_c0fd7_row7_col0, #T_c0fd7_row7_col1, #T_c0fd7_row9_col0, #T_c0fd7_row9_col1 {
#   background-color: plum;
# }
# #T_c0fd7_row11_col0, #T_c0fd7_row11_col1 {
#   background-color: cornflowerblue;
# }
# </style>
# <table id="T_c0fd7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0fd7_level0_col0" class="col_heading level0 col0" >Observed Toxicity</th>
#       <th id="T_c0fd7_level0_col1" class="col_heading level0 col1" >Predicted Toxicity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0fd7_level0_row0" class="row_heading level0 row0" >1) DQ-12, </th>
#       <td id="T_c0fd7_row0_col0" class="data row0 col0" >Non-Toxic</td>
#       <td id="T_c0fd7_row0_col1" class="data row0 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_c0fd7_level0_row1" class="row_heading level0 row1" >2) JRCNM01005a (TiO2, =NM-105),</th>
#       <td id="T_c0fd7_row1_col0" class="data row1 col0" >Non-Toxic</td>
#       <td id="T_c0fd7_row1_col1" class="data row1 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_c0fd7_level0_row2" class="row_heading level0 row2" >3) JRCNM01101a (ZnO, =NM111),</th>
#       <td id="T_c0fd7_row2_col0" class="data row2 col0" >Non-Toxic</td>
#       <td id="T_c0fd7_row2_col1" class="data row2 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_c0fd7_level0_row3" class="row_heading level0 row3" >4) JRCNM04000a (MWCNT, =NM-400),</th>
#       <td id="T_c0fd7_row3_col0" class="data row3 col0" >Non-Toxic</td>
#       <td id="T_c0fd7_row3_col1" class="data row3 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_c0fd7_level0_row4" class="row_heading level0 row4" >5) JRCNM04002a (MWCNT, =NM-402),</th>
#       <td id="T_c0fd7_row4_col0" class="data row4 col0" >Non-Toxic</td>
#       <td id="T_c0fd7_row4_col1" class="data row4 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_c0fd7_level0_row5" class="row_heading level0 row5" >6) JRCNM40011a (Mitsui-7),</th>
#       <td id="T_c0fd7_row5_col0" class="data row5 col0" >Non-Toxic</td>
#       <td id="T_c0fd7_row5_col1" class="data row5 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_c0fd7_level0_row6" class="row_heading level0 row6" >7) JRCNM50001a (BaSO4, =NM220),</th>
#       <td id="T_c0fd7_row6_col0" class="data row6 col0" >Non-Toxic</td>
#       <td id="T_c0fd7_row6_col1" class="data row6 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_c0fd7_level0_row7" class="row_heading level0 row7" >8) JRCNM62101a (ZnO),</th>
#       <td id="T_c0fd7_row7_col0" class="data row7 col0" >Toxic</td>
#       <td id="T_c0fd7_row7_col1" class="data row7 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_c0fd7_level0_row8" class="row_heading level0 row8" >9) NM-105 (TiO2)</th>
#       <td id="T_c0fd7_row8_col0" class="data row8 col0" >Non-Toxic</td>
#       <td id="T_c0fd7_row8_col1" class="data row8 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_c0fd7_level0_row9" class="row_heading level0 row9" >10) NM-110 (ZnO), </th>
#       <td id="T_c0fd7_row9_col0" class="data row9 col0" >Toxic</td>
#       <td id="T_c0fd7_row9_col1" class="data row9 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_c0fd7_level0_row10" class="row_heading level0 row10" >11) NM-111 (ZnO), </th>
#       <td id="T_c0fd7_row10_col0" class="data row10 col0" >Non-Toxic</td>
#       <td id="T_c0fd7_row10_col1" class="data row10 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_c0fd7_level0_row11" class="row_heading level0 row11" >12) NM-113 (ZnO),</th>
#       <td id="T_c0fd7_row11_col0" class="data row11 col0" >Non-Toxic</td>
#       <td id="T_c0fd7_row11_col1" class="data row11 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_c0fd7_level0_row12" class="row_heading level0 row12" >13) NM-200 (SiO2),</th>
#       <td id="T_c0fd7_row12_col0" class="data row12 col0" >Non-Toxic</td>
#       <td id="T_c0fd7_row12_col1" class="data row12 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_c0fd7_level0_row13" class="row_heading level0 row13" >14) NM-212 (CeO2),</th>
#       <td id="T_c0fd7_row13_col0" class="data row13 col0" >Non-Toxic</td>
#       <td id="T_c0fd7_row13_col1" class="data row13 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_c0fd7_level0_row14" class="row_heading level0 row14" >15) NM-220 (BaSO4),</th>
#       <td id="T_c0fd7_row14_col0" class="data row14 col0" >Non-Toxic</td>
#       <td id="T_c0fd7_row14_col1" class="data row14 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_c0fd7_level0_row15" class="row_heading level0 row15" >16) NM-300k (Ag),</th>
#       <td id="T_c0fd7_row15_col0" class="data row15 col0" >Toxic</td>
#       <td id="T_c0fd7_row15_col1" class="data row15 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_c0fd7_level0_row16" class="row_heading level0 row16" >18) NM-302 (Ag-rod),</th>
#       <td id="T_c0fd7_row16_col0" class="data row16 col0" >Toxic</td>
#       <td id="T_c0fd7_row16_col1" class="data row16 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_c0fd7_level0_row17" class="row_heading level0 row17" >20) TiO2 E171-Venator, </th>
#       <td id="T_c0fd7_row17_col0" class="data row17 col0" >Non-Toxic</td>
#       <td id="T_c0fd7_row17_col1" class="data row17 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_c0fd7_level0_row18" class="row_heading level0 row18" >21) JRCNM02102a (CeO2), </th>
#       <td id="T_c0fd7_row18_col0" class="data row18 col0" >Non-Toxic</td>
#       <td id="T_c0fd7_row18_col1" class="data row18 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_c0fd7_level0_row19" class="row_heading level0 row19" >22) Sigma Silver #576832, </th>
#       <td id="T_c0fd7_row19_col0" class="data row19 col0" >Toxic</td>
#       <td id="T_c0fd7_row19_col1" class="data row19 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_c0fd7_level0_row20" class="row_heading level0 row20" >23) carbon black,</th>
#       <td id="T_c0fd7_row20_col0" class="data row20 col0" >Non-Toxic</td>
#       <td id="T_c0fd7_row20_col1" class="data row20 col1" >Non-Toxic</td>
#     </tr>
#   </tbody>
# </table>

# %%
hep.mean_calc
# Out:
# TRAIN SET:
# Accuracy = 0.9648033126293997
# Precison = 0.8680124223602484
# Recall = 1.0
# tn = 11.472049689440993
# fp = 0.5279503105590062
# fn = 0.0
# tp = 3.0
#
# TEST SET:
# Accuracy = 0.835977066411849
# Precison = 0.7953352444656794
# Recall = 0.835977066411849
# tn = 3.846918299092212
# fp = 0.15308170090778786
# fn = 0.831055900621118
# tp = 1.168944099378882
# 0

# %% [markdown]
# # DNA test

# %%
train_a549 = pd.read_excel("Data/DNA/a549_data.xlsx", sheet_name=1, index_col=0)
test_a549 = pd.read_excel("Data/DNA/a549_data.xlsx", sheet_name=2, index_col=0)
toxic_a549 = pd.read_excel("Data/DNA/a549_data.xlsx", sheet_name=3, index_col=0)

train_beas = pd.read_excel("Data/DNA/beas_data.xlsx", sheet_name=1, index_col=0)
test_beas = pd.read_excel("Data/DNA/beas_data.xlsx", sheet_name=2, index_col=0)
toxic_beas = pd.read_excel("Data/DNA/beas_data.xlsx", sheet_name=3, index_col=0)

train_hep = pd.read_excel("Data/DNA/hepg2_data.xlsx", sheet_name=1, index_col=0)
test_hep = pd.read_excel("Data/DNA/hepg2_data.xlsx", sheet_name=2, index_col=0)
toxic_hep = pd.read_excel("Data/DNA/hepg2_data.xlsx", sheet_name=3, index_col=0)

# %%
a549 = CombinationModel(my_model, train_a549,test_a549,toxic_a549,2)
beas = CombinationModel(my_model, train_beas,test_beas,toxic_beas,2)
hep = CombinationModel(my_model, train_hep,test_hep,toxic_hep,2)

# %% [markdown]
# ## Model A549

# %%
# a549.show_models = False
# a549.create_models

# %%
# a549.mean_calc

# %%
obs = pd.read_excel("Data/DNA/a549_data.xlsx", index_col=0)
table = compare(obs, a549.predict_on_test)
table
# Out:
# __predOnTest from func:  True
# CREATE_DATA - number of sets: 10914
# __predOnTest GLOBAL:  True
# ELSE
# <style type="text/css">
# #T_e3f1a_row0_col0, #T_e3f1a_row0_col1, #T_e3f1a_row1_col0, #T_e3f1a_row1_col1, #T_e3f1a_row2_col0, #T_e3f1a_row2_col1, #T_e3f1a_row6_col0, #T_e3f1a_row6_col1, #T_e3f1a_row8_col0, #T_e3f1a_row8_col1, #T_e3f1a_row10_col0, #T_e3f1a_row10_col1, #T_e3f1a_row13_col0, #T_e3f1a_row13_col1, #T_e3f1a_row14_col0, #T_e3f1a_row14_col1, #T_e3f1a_row17_col0, #T_e3f1a_row17_col1, #T_e3f1a_row18_col0, #T_e3f1a_row18_col1 {
#   background-color: white;
# }
# #T_e3f1a_row3_col0, #T_e3f1a_row3_col1, #T_e3f1a_row12_col0, #T_e3f1a_row12_col1, #T_e3f1a_row16_col0, #T_e3f1a_row16_col1 {
#   background-color: cornflowerblue;
# }
# #T_e3f1a_row4_col0, #T_e3f1a_row4_col1, #T_e3f1a_row5_col0, #T_e3f1a_row5_col1, #T_e3f1a_row7_col0, #T_e3f1a_row7_col1, #T_e3f1a_row9_col0, #T_e3f1a_row9_col1, #T_e3f1a_row11_col0, #T_e3f1a_row11_col1, #T_e3f1a_row15_col0, #T_e3f1a_row15_col1, #T_e3f1a_row19_col0, #T_e3f1a_row19_col1, #T_e3f1a_row20_col0, #T_e3f1a_row20_col1 {
#   background-color: plum;
# }
# </style>
# <table id="T_e3f1a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3f1a_level0_col0" class="col_heading level0 col0" >Observed Toxicity</th>
#       <th id="T_e3f1a_level0_col1" class="col_heading level0 col1" >Predicted Toxicity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3f1a_level0_row0" class="row_heading level0 row0" >1) DQ-12, </th>
#       <td id="T_e3f1a_row0_col0" class="data row0 col0" >Non-Toxic</td>
#       <td id="T_e3f1a_row0_col1" class="data row0 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_e3f1a_level0_row1" class="row_heading level0 row1" >2) JRCNM01005a (TiO2, =NM-105),</th>
#       <td id="T_e3f1a_row1_col0" class="data row1 col0" >Non-Toxic</td>
#       <td id="T_e3f1a_row1_col1" class="data row1 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_e3f1a_level0_row2" class="row_heading level0 row2" >3) JRCNM01101a (ZnO, =NM111),</th>
#       <td id="T_e3f1a_row2_col0" class="data row2 col0" >Toxic</td>
#       <td id="T_e3f1a_row2_col1" class="data row2 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_e3f1a_level0_row3" class="row_heading level0 row3" >4) JRCNM04000a (MWCNT, =NM-400),</th>
#       <td id="T_e3f1a_row3_col0" class="data row3 col0" >Non-Toxic</td>
#       <td id="T_e3f1a_row3_col1" class="data row3 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_e3f1a_level0_row4" class="row_heading level0 row4" >5) JRCNM04002a (MWCNT, =NM-402),</th>
#       <td id="T_e3f1a_row4_col0" class="data row4 col0" >Toxic</td>
#       <td id="T_e3f1a_row4_col1" class="data row4 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_e3f1a_level0_row5" class="row_heading level0 row5" >6) JRCNM40011a (Mitsui-7),</th>
#       <td id="T_e3f1a_row5_col0" class="data row5 col0" >Toxic</td>
#       <td id="T_e3f1a_row5_col1" class="data row5 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_e3f1a_level0_row6" class="row_heading level0 row6" >7) JRCNM50001a (BaSO4, =NM220),</th>
#       <td id="T_e3f1a_row6_col0" class="data row6 col0" >Non-Toxic</td>
#       <td id="T_e3f1a_row6_col1" class="data row6 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_e3f1a_level0_row7" class="row_heading level0 row7" >8) JRCNM62101a (ZnO),</th>
#       <td id="T_e3f1a_row7_col0" class="data row7 col0" >Toxic</td>
#       <td id="T_e3f1a_row7_col1" class="data row7 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_e3f1a_level0_row8" class="row_heading level0 row8" >9) NM-105 (TiO2)</th>
#       <td id="T_e3f1a_row8_col0" class="data row8 col0" >Non-Toxic</td>
#       <td id="T_e3f1a_row8_col1" class="data row8 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_e3f1a_level0_row9" class="row_heading level0 row9" >10) NM-110 (ZnO), </th>
#       <td id="T_e3f1a_row9_col0" class="data row9 col0" >Toxic</td>
#       <td id="T_e3f1a_row9_col1" class="data row9 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_e3f1a_level0_row10" class="row_heading level0 row10" >11) NM-111 (ZnO), </th>
#       <td id="T_e3f1a_row10_col0" class="data row10 col0" >Toxic</td>
#       <td id="T_e3f1a_row10_col1" class="data row10 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_e3f1a_level0_row11" class="row_heading level0 row11" >12) NM-113 (ZnO),</th>
#       <td id="T_e3f1a_row11_col0" class="data row11 col0" >Toxic</td>
#       <td id="T_e3f1a_row11_col1" class="data row11 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_e3f1a_level0_row12" class="row_heading level0 row12" >13) NM-200 (SiO2),</th>
#       <td id="T_e3f1a_row12_col0" class="data row12 col0" >Non-Toxic</td>
#       <td id="T_e3f1a_row12_col1" class="data row12 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_e3f1a_level0_row13" class="row_heading level0 row13" >14) NM-212 (CeO2),</th>
#       <td id="T_e3f1a_row13_col0" class="data row13 col0" >Non-Toxic</td>
#       <td id="T_e3f1a_row13_col1" class="data row13 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_e3f1a_level0_row14" class="row_heading level0 row14" >15) NM-220 (BaSO4),</th>
#       <td id="T_e3f1a_row14_col0" class="data row14 col0" >Non-Toxic</td>
#       <td id="T_e3f1a_row14_col1" class="data row14 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_e3f1a_level0_row15" class="row_heading level0 row15" >16) NM-300k (Ag),</th>
#       <td id="T_e3f1a_row15_col0" class="data row15 col0" >Toxic</td>
#       <td id="T_e3f1a_row15_col1" class="data row15 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_e3f1a_level0_row16" class="row_heading level0 row16" >18) NM-302 (Ag-rod),</th>
#       <td id="T_e3f1a_row16_col0" class="data row16 col0" >Non-Toxic</td>
#       <td id="T_e3f1a_row16_col1" class="data row16 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_e3f1a_level0_row17" class="row_heading level0 row17" >20) TiO2 E171-Venator, </th>
#       <td id="T_e3f1a_row17_col0" class="data row17 col0" >Non-Toxic</td>
#       <td id="T_e3f1a_row17_col1" class="data row17 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_e3f1a_level0_row18" class="row_heading level0 row18" >21) JRCNM02102a (CeO2), </th>
#       <td id="T_e3f1a_row18_col0" class="data row18 col0" >Non-Toxic</td>
#       <td id="T_e3f1a_row18_col1" class="data row18 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_e3f1a_level0_row19" class="row_heading level0 row19" >22) Sigma Silver #576832, </th>
#       <td id="T_e3f1a_row19_col0" class="data row19 col0" >Toxic</td>
#       <td id="T_e3f1a_row19_col1" class="data row19 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_e3f1a_level0_row20" class="row_heading level0 row20" >23) carbon black,</th>
#       <td id="T_e3f1a_row20_col0" class="data row20 col0" >Toxic</td>
#       <td id="T_e3f1a_row20_col1" class="data row20 col1" >Non-Toxic</td>
#     </tr>
#   </tbody>
# </table>

# %%
a549.mean_calc
# Out:
# TRAIN SET:
# Accuracy = 0.8852788467411887
# Precison = 0.9801335001101356
# Recall = 0.8086746380795309
# tn = 6.809785596481583
# fp = 0.1902144035184167
# fn = 1.530602895363753
# tp = 6.469397104636247
#
# TEST SET:
# Accuracy = 0.6029717182823285
# Precison = 0.5421362470221733
# Recall = 0.6029717182823285
# tn = 2.8080447132123876
# fp = 1.1919552867876122
# fn = 1.1902144035184168
# tp = 0.8097855964815833
# 0

# %% [markdown]
# ## Model Beas

# %%
# beas.show_models = False
# beas.create_models

# %%
# beas.mean_calc

# %%
obs = pd.read_excel("Data/DNA/beas_data.xlsx", index_col=0)
table = compare(obs, beas.predict_on_test)
table
# Out:
# __predOnTest from func:  True
# CREATE_DATA - number of sets: 8997
# __predOnTest GLOBAL:  True
# ELSE
# <style type="text/css">
# #T_7c6dc_row0_col0, #T_7c6dc_row0_col1, #T_7c6dc_row3_col0, #T_7c6dc_row3_col1, #T_7c6dc_row4_col0, #T_7c6dc_row4_col1, #T_7c6dc_row6_col0, #T_7c6dc_row6_col1, #T_7c6dc_row9_col0, #T_7c6dc_row9_col1, #T_7c6dc_row11_col0, #T_7c6dc_row11_col1, #T_7c6dc_row12_col0, #T_7c6dc_row12_col1, #T_7c6dc_row13_col0, #T_7c6dc_row13_col1, #T_7c6dc_row14_col0, #T_7c6dc_row14_col1, #T_7c6dc_row15_col0, #T_7c6dc_row15_col1, #T_7c6dc_row16_col0, #T_7c6dc_row16_col1, #T_7c6dc_row18_col0, #T_7c6dc_row18_col1, #T_7c6dc_row19_col0, #T_7c6dc_row19_col1 {
#   background-color: white;
# }
# #T_7c6dc_row1_col0, #T_7c6dc_row1_col1, #T_7c6dc_row2_col0, #T_7c6dc_row2_col1, #T_7c6dc_row8_col0, #T_7c6dc_row8_col1 {
#   background-color: cornflowerblue;
# }
# #T_7c6dc_row5_col0, #T_7c6dc_row5_col1, #T_7c6dc_row7_col0, #T_7c6dc_row7_col1, #T_7c6dc_row10_col0, #T_7c6dc_row10_col1, #T_7c6dc_row17_col0, #T_7c6dc_row17_col1, #T_7c6dc_row20_col0, #T_7c6dc_row20_col1 {
#   background-color: plum;
# }
# </style>
# <table id="T_7c6dc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c6dc_level0_col0" class="col_heading level0 col0" >Observed Toxicity</th>
#       <th id="T_7c6dc_level0_col1" class="col_heading level0 col1" >Predicted Toxicity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c6dc_level0_row0" class="row_heading level0 row0" >1) DQ-12, </th>
#       <td id="T_7c6dc_row0_col0" class="data row0 col0" >Non-Toxic</td>
#       <td id="T_7c6dc_row0_col1" class="data row0 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_7c6dc_level0_row1" class="row_heading level0 row1" >2) JRCNM01005a (TiO2, =NM-105),</th>
#       <td id="T_7c6dc_row1_col0" class="data row1 col0" >Non-Toxic</td>
#       <td id="T_7c6dc_row1_col1" class="data row1 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_7c6dc_level0_row2" class="row_heading level0 row2" >3) JRCNM01101a (ZnO, =NM111),</th>
#       <td id="T_7c6dc_row2_col0" class="data row2 col0" >Non-Toxic</td>
#       <td id="T_7c6dc_row2_col1" class="data row2 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_7c6dc_level0_row3" class="row_heading level0 row3" >4) JRCNM04000a (MWCNT, =NM-400),</th>
#       <td id="T_7c6dc_row3_col0" class="data row3 col0" >Non-Toxic</td>
#       <td id="T_7c6dc_row3_col1" class="data row3 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_7c6dc_level0_row4" class="row_heading level0 row4" >5) JRCNM04002a (MWCNT, =NM-402),</th>
#       <td id="T_7c6dc_row4_col0" class="data row4 col0" >Non-Toxic</td>
#       <td id="T_7c6dc_row4_col1" class="data row4 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_7c6dc_level0_row5" class="row_heading level0 row5" >6) JRCNM40011a (Mitsui-7) MWCNT,</th>
#       <td id="T_7c6dc_row5_col0" class="data row5 col0" >Toxic</td>
#       <td id="T_7c6dc_row5_col1" class="data row5 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_7c6dc_level0_row6" class="row_heading level0 row6" >7) JRCNM50001a (BaSO4, =NM220),</th>
#       <td id="T_7c6dc_row6_col0" class="data row6 col0" >Non-Toxic</td>
#       <td id="T_7c6dc_row6_col1" class="data row6 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_7c6dc_level0_row7" class="row_heading level0 row7" >8) JRCNM62101a (ZnO),</th>
#       <td id="T_7c6dc_row7_col0" class="data row7 col0" >Toxic</td>
#       <td id="T_7c6dc_row7_col1" class="data row7 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_7c6dc_level0_row8" class="row_heading level0 row8" >9) NM-105 (TiO2)</th>
#       <td id="T_7c6dc_row8_col0" class="data row8 col0" >Non-Toxic</td>
#       <td id="T_7c6dc_row8_col1" class="data row8 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_7c6dc_level0_row9" class="row_heading level0 row9" >10) NM-110 (ZnO), </th>
#       <td id="T_7c6dc_row9_col0" class="data row9 col0" >Non-Toxic</td>
#       <td id="T_7c6dc_row9_col1" class="data row9 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_7c6dc_level0_row10" class="row_heading level0 row10" >11) NM-111 (ZnO), </th>
#       <td id="T_7c6dc_row10_col0" class="data row10 col0" >Toxic</td>
#       <td id="T_7c6dc_row10_col1" class="data row10 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_7c6dc_level0_row11" class="row_heading level0 row11" >12) NM-113 (ZnO),</th>
#       <td id="T_7c6dc_row11_col0" class="data row11 col0" >Non-Toxic</td>
#       <td id="T_7c6dc_row11_col1" class="data row11 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_7c6dc_level0_row12" class="row_heading level0 row12" >13) NM-200 (SiO2),</th>
#       <td id="T_7c6dc_row12_col0" class="data row12 col0" >Non-Toxic</td>
#       <td id="T_7c6dc_row12_col1" class="data row12 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_7c6dc_level0_row13" class="row_heading level0 row13" >14) NM-212 (CeO2),</th>
#       <td id="T_7c6dc_row13_col0" class="data row13 col0" >Non-Toxic</td>
#       <td id="T_7c6dc_row13_col1" class="data row13 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_7c6dc_level0_row14" class="row_heading level0 row14" >15) NM-220 (BaSO4),</th>
#       <td id="T_7c6dc_row14_col0" class="data row14 col0" >Non-Toxic</td>
#       <td id="T_7c6dc_row14_col1" class="data row14 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_7c6dc_level0_row15" class="row_heading level0 row15" >16) NM-300k (Ag),</th>
#       <td id="T_7c6dc_row15_col0" class="data row15 col0" >Toxic</td>
#       <td id="T_7c6dc_row15_col1" class="data row15 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_7c6dc_level0_row16" class="row_heading level0 row16" >18) NM-302 (Ag-rod),</th>
#       <td id="T_7c6dc_row16_col0" class="data row16 col0" >Toxic</td>
#       <td id="T_7c6dc_row16_col1" class="data row16 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_7c6dc_level0_row17" class="row_heading level0 row17" >20) TiO2 E171-Venator, </th>
#       <td id="T_7c6dc_row17_col0" class="data row17 col0" >Toxic</td>
#       <td id="T_7c6dc_row17_col1" class="data row17 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_7c6dc_level0_row18" class="row_heading level0 row18" >21) JRCNM02102a (CeO2), </th>
#       <td id="T_7c6dc_row18_col0" class="data row18 col0" >Non-Toxic</td>
#       <td id="T_7c6dc_row18_col1" class="data row18 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_7c6dc_level0_row19" class="row_heading level0 row19" >22) Sigma Silver #576832, </th>
#       <td id="T_7c6dc_row19_col0" class="data row19 col0" >Non-Toxic</td>
#       <td id="T_7c6dc_row19_col1" class="data row19 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_7c6dc_level0_row20" class="row_heading level0 row20" >23) carbon black,</th>
#       <td id="T_7c6dc_row20_col0" class="data row20 col0" >Toxic</td>
#       <td id="T_7c6dc_row20_col1" class="data row20 col1" >Non-Toxic</td>
#     </tr>
#   </tbody>
# </table>

# %%
beas.mean_calc
# Out:
# TRAIN SET:
# Accuracy = 0.8384646734096552
# Precison = 0.8304048599813856
# Recall = 0.8201400466822273
# tn = 8.47626986773369
# fp = 1.523730132266311
# fn = 0.8992997665888629
# tp = 4.100700233411137
#
# TEST SET:
# Accuracy = 0.5377533251824682
# Precison = 0.500655774146938
# Recall = 0.5377533251824682
# tn = 2.499722129598755
# fp = 1.500277870401245
# fn = 1.2732021785039458
# tp = 0.7267978214960542
# 0

# %% [markdown]
# ## Model HepG2

# %%
# hep.show_models = False
# hep.create_models

# %%
# hep.mean_calc

# %%
obs = pd.read_excel("Data/DNA/hepg2_data.xlsx", index_col=0)
table = compare(obs, hep.predict_on_test)
table
# Out:
# __predOnTest from func:  True
# CREATE_DATA - number of sets: 8658
# __predOnTest GLOBAL:  True
# ELSE
# <style type="text/css">
# #T_488b5_row0_col0, #T_488b5_row0_col1, #T_488b5_row1_col0, #T_488b5_row1_col1, #T_488b5_row2_col0, #T_488b5_row2_col1, #T_488b5_row3_col0, #T_488b5_row3_col1, #T_488b5_row4_col0, #T_488b5_row4_col1, #T_488b5_row5_col0, #T_488b5_row5_col1, #T_488b5_row6_col0, #T_488b5_row6_col1, #T_488b5_row8_col0, #T_488b5_row8_col1, #T_488b5_row10_col0, #T_488b5_row10_col1, #T_488b5_row12_col0, #T_488b5_row12_col1, #T_488b5_row13_col0, #T_488b5_row13_col1, #T_488b5_row14_col0, #T_488b5_row14_col1, #T_488b5_row17_col0, #T_488b5_row17_col1, #T_488b5_row18_col0, #T_488b5_row18_col1, #T_488b5_row19_col0, #T_488b5_row19_col1, #T_488b5_row20_col0, #T_488b5_row20_col1 {
#   background-color: white;
# }
# #T_488b5_row7_col0, #T_488b5_row7_col1, #T_488b5_row15_col0, #T_488b5_row15_col1 {
#   background-color: plum;
# }
# #T_488b5_row9_col0, #T_488b5_row9_col1, #T_488b5_row11_col0, #T_488b5_row11_col1, #T_488b5_row16_col0, #T_488b5_row16_col1 {
#   background-color: cornflowerblue;
# }
# </style>
# <table id="T_488b5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_488b5_level0_col0" class="col_heading level0 col0" >Observed Toxicity</th>
#       <th id="T_488b5_level0_col1" class="col_heading level0 col1" >Predicted Toxicity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_488b5_level0_row0" class="row_heading level0 row0" >1) DQ-12, </th>
#       <td id="T_488b5_row0_col0" class="data row0 col0" >Non-Toxic</td>
#       <td id="T_488b5_row0_col1" class="data row0 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_488b5_level0_row1" class="row_heading level0 row1" >2) JRCNM01005a (TiO2, =NM-105),</th>
#       <td id="T_488b5_row1_col0" class="data row1 col0" >Non-Toxic</td>
#       <td id="T_488b5_row1_col1" class="data row1 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_488b5_level0_row2" class="row_heading level0 row2" >3) JRCNM01101a (ZnO, =NM111),</th>
#       <td id="T_488b5_row2_col0" class="data row2 col0" >Toxic</td>
#       <td id="T_488b5_row2_col1" class="data row2 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_488b5_level0_row3" class="row_heading level0 row3" >4) JRCNM04000a (MWCNT, =NM-400),</th>
#       <td id="T_488b5_row3_col0" class="data row3 col0" >Non-Toxic</td>
#       <td id="T_488b5_row3_col1" class="data row3 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_488b5_level0_row4" class="row_heading level0 row4" >5) JRCNM04002a (MWCNT, =NM-402),</th>
#       <td id="T_488b5_row4_col0" class="data row4 col0" >Non-Toxic</td>
#       <td id="T_488b5_row4_col1" class="data row4 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_488b5_level0_row5" class="row_heading level0 row5" >6) JRCNM40011a (Mitsui-7),</th>
#       <td id="T_488b5_row5_col0" class="data row5 col0" >Non-Toxic</td>
#       <td id="T_488b5_row5_col1" class="data row5 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_488b5_level0_row6" class="row_heading level0 row6" >7) JRCNM50001a (BaSO4, =NM220),</th>
#       <td id="T_488b5_row6_col0" class="data row6 col0" >Non-Toxic</td>
#       <td id="T_488b5_row6_col1" class="data row6 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_488b5_level0_row7" class="row_heading level0 row7" >8) JRCNM62101a (ZnO),</th>
#       <td id="T_488b5_row7_col0" class="data row7 col0" >Toxic</td>
#       <td id="T_488b5_row7_col1" class="data row7 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_488b5_level0_row8" class="row_heading level0 row8" >9) NM-105 (TiO2)</th>
#       <td id="T_488b5_row8_col0" class="data row8 col0" >Non-Toxic</td>
#       <td id="T_488b5_row8_col1" class="data row8 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_488b5_level0_row9" class="row_heading level0 row9" >10) NM-110 (ZnO), </th>
#       <td id="T_488b5_row9_col0" class="data row9 col0" >Non-Toxic</td>
#       <td id="T_488b5_row9_col1" class="data row9 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_488b5_level0_row10" class="row_heading level0 row10" >11) NM-111 (ZnO), </th>
#       <td id="T_488b5_row10_col0" class="data row10 col0" >Toxic</td>
#       <td id="T_488b5_row10_col1" class="data row10 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_488b5_level0_row11" class="row_heading level0 row11" >12) NM-113 (ZnO),</th>
#       <td id="T_488b5_row11_col0" class="data row11 col0" >Non-Toxic</td>
#       <td id="T_488b5_row11_col1" class="data row11 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_488b5_level0_row12" class="row_heading level0 row12" >13) NM-200 (SiO2),</th>
#       <td id="T_488b5_row12_col0" class="data row12 col0" >Non-Toxic</td>
#       <td id="T_488b5_row12_col1" class="data row12 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_488b5_level0_row13" class="row_heading level0 row13" >14) NM-212 (CeO2),</th>
#       <td id="T_488b5_row13_col0" class="data row13 col0" >Non-Toxic</td>
#       <td id="T_488b5_row13_col1" class="data row13 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_488b5_level0_row14" class="row_heading level0 row14" >15) NM-220 (BaSO4),</th>
#       <td id="T_488b5_row14_col0" class="data row14 col0" >Non-Toxic</td>
#       <td id="T_488b5_row14_col1" class="data row14 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_488b5_level0_row15" class="row_heading level0 row15" >16) NM-300k (Ag),</th>
#       <td id="T_488b5_row15_col0" class="data row15 col0" >Toxic</td>
#       <td id="T_488b5_row15_col1" class="data row15 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_488b5_level0_row16" class="row_heading level0 row16" >18) NM-302 (Ag-rod),</th>
#       <td id="T_488b5_row16_col0" class="data row16 col0" >Non-Toxic</td>
#       <td id="T_488b5_row16_col1" class="data row16 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_488b5_level0_row17" class="row_heading level0 row17" >20) TiO2 E171-Venator, </th>
#       <td id="T_488b5_row17_col0" class="data row17 col0" >Non-Toxic</td>
#       <td id="T_488b5_row17_col1" class="data row17 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_488b5_level0_row18" class="row_heading level0 row18" >21) JRCNM02102a (CeO2), </th>
#       <td id="T_488b5_row18_col0" class="data row18 col0" >Non-Toxic</td>
#       <td id="T_488b5_row18_col1" class="data row18 col1" >Non-Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_488b5_level0_row19" class="row_heading level0 row19" >22) Sigma Silver #576832, </th>
#       <td id="T_488b5_row19_col0" class="data row19 col0" >Toxic</td>
#       <td id="T_488b5_row19_col1" class="data row19 col1" >Toxic</td>
#     </tr>
#     <tr>
#       <th id="T_488b5_level0_row20" class="row_heading level0 row20" >23) carbon black,</th>
#       <td id="T_488b5_row20_col0" class="data row20 col0" >Non-Toxic</td>
#       <td id="T_488b5_row20_col1" class="data row20 col1" >Non-Toxic</td>
#     </tr>
#   </tbody>
# </table>

# %%
hep.mean_calc
# Out:
# TRAIN SET:
# Accuracy = 0.9141141141141144
# Precison = 0.7192192192192193
# Recall = 1.0
# tn = 10.711711711711711
# fp = 1.2882882882882882
# fn = 0.0
# tp = 3.0
#
# TEST SET:
# Accuracy = 0.7972972972972971
# Precison = 0.7631631631631632
# Recall = 0.7972972972972971
# tn = 3.8168168168168166
# fp = 0.1831831831831832
# fn = 1.033033033033033
# tp = 0.9669669669669669
# 0
